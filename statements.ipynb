# %% [markdown]
# <a href="https://colab.research.google.com/github/Hicham-AZ/functions-from-zero/blob/main/statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Learning Statements

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ### Variables

# %%
variable = 1
